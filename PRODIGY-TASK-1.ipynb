# %% [markdown]
# # Task 1
# # Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\HP\Downloads\archive (2)\Age Prediction.csv")
data
# Out:
#          ID Age_group  Age  Gender  PAQ605  Body Mass Index  \
# 0     73564     Adult   61       2       2             35.7
# 1     73568     Adult   26       2       2             20.3
# 2     73576     Adult   16       1       2             23.2
# 3     73577     Adult   32       1       2             28.9
# 4     73580     Adult   38       2       1             35.9
# ...     ...       ...  ...     ...     ...              ...
# 2273  83711     Adult   38       2       2             33.5
# 2274  83712     Adult   61       1       2             30.0
# 2275  83713     Adult   34       1       2             23.7
# 2276  83718     Adult   60       2       2             27.4
# 2277  83727     Adult   26       1       2             24.5
#
#       Blood Glucose after fasting  Diabetic or not  Respondent's Oral  \
# 0                             110                2                150
# 1                              89                2                 80
# ...

# %%
print(data.head)
print(data.info)
# Out:
# <bound method NDFrame.head of          ID Age_group  Age  Gender  PAQ605  Body Mass Index  \
# 0     73564     Adult   61       2       2             35.7
# 1     73568     Adult   26       2       2             20.3
# 2     73576     Adult   16       1       2             23.2
# 3     73577     Adult   32       1       2             28.9
# 4     73580     Adult   38       2       1             35.9
# ...     ...       ...  ...     ...     ...              ...
# 2273  83711     Adult   38       2       2             33.5
# 2274  83712     Adult   61       1       2             30.0
# 2275  83713     Adult   34       1       2             23.7
# 2276  83718     Adult   60       2       2             27.4
# 2277  83727     Adult   26       1       2             24.5
#
#       Blood Glucose after fasting  Diabetic or not  Respondent's Oral  \
# 0                             110                2                150
# 1                              89                2                 80
# ...

# %%
#create an histogram
plt.Figure(figsize=(10,6))
plt.hist(data['Age'],bins=10,edgecolor="black")
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequence')
plt.grid(True)
plt.show()

# %%
# Bar chart 
gender_counts = data['Gender'].value_counts()  
plt.figure(figsize=(8, 6))
plt.bar(gender_counts.index, gender_counts.values, color=['skyblue', 'lightcoral'], edgecolor="black")
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(ticks=gender_counts.index, labels=['Male', 'Female'], rotation=0)  
plt.show()
